# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\asrya\AppData\Local\Temp\ipykernel_2616\265554930.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import matplotlib.image as mpimg

# %%
image = mpimg.imread('03spongebob_xp-videoSixteenByNineJumbo1600.jpg')

# %%
image
# Out:
# array([[[187, 212,  46],
#         [187, 215,  45],
#         [186, 216,  42],
#         ...,
#         [ 29, 142, 222],
#         [ 29, 142, 222],
#         [ 29, 142, 222]],
#
#        [[182, 207,  41],
#         [183, 211,  41],
#         [183, 213,  39],
#         ...,
#         [ 30, 143, 223],
#         [ 30, 143, 223],
#         [ 30, 143, 223]],
#
#        [[180, 205,  39],
#         [183, 211,  41],
#         [181, 214,  39],
#         ...,
#         [ 30, 143, 223],
#         [ 30, 143, 223],
#         [ 30, 143, 223]],
#
#        ...,
#
#        [[226, 234, 185],
#         [226, 234, 185],
#         [226, 234, 185],
#         ...,
#         [158, 181, 101],
#         [153, 176,  96],
#         [148, 171,  91]],
#
#        [[226, 234, 185],
#         [226, 234, 185],
#         [226, 234, 185],
#         ...,
#         [161, 184, 104],
#         [154, 177,  97],
#         [148, 171,  91]],
#
#        [[226, 234, 185],
#         [226, 234, 185],
#         [226, 234, 185],
# ...

# %%
plt.imshow(image)

# %%
image.shape      #215, 75, 80         #190, 210, 100             165, 165, 55     90, 120, 40
# Out:
# (900, 1600, 3)

# %%
arr = np.array(image)

# %%
arr[500, 1000]
# Out:
# array([233, 228,  15], dtype=uint8)

# %%
arr.shape
# Out:
# (900, 1600, 3)

# %%
image[450, 350]
# Out:
# array([235, 139, 125], dtype=uint8)

# %%
image.shape
# Out:
# (900, 1600, 3)

# %%
for i in range(900):
    for j in range(1600):
        if 200 <= arr[i, j, 0] <= 250 and 100 <= arr[i, j, 1] <= 155 and 80 <= arr[i, j, 2] <= 140: #patrik
            arr[i, j] = [233, 228, 15]
        elif 220 <= arr[i, j, 0] <= 250 and 210 <= arr[i, j, 1] <= 245 and 0 <= arr[i, j, 2] <= 30:  # bob
            arr[i, j] = [235, 139, 125]
        elif 170 <= arr[i, j, 0] <= 210 and 190 <= arr[i, j, 1] <= 240 and 70 <= arr[i, j, 2] <= 130:  # bob aj kom
            arr[i, j] = [235, 139, 125]
        elif 140 <= arr[i, j, 0] <= 190 and 140 <= arr[i, j, 1] <= 190 and 20 <= arr[i, j, 2] <= 80:  # bob kloraakner
            arr[i, j] = [225, 75, 75]
        elif 50 <= arr[i, j, 0] <= 130 and 90 <= arr[i, j, 1] <= 150 and 10 <= arr[i, j, 2] <= 80:  # bob kloraakner
            arr[i, j] = [225, 75, 75]

# %%
arr[400, 200:400]
# Out:
# array([[ 44, 103, 197],
#        [ 31, 108, 214],
#        [ 23, 113, 225],
#        [ 20, 115, 231],
#        [ 21, 116, 234],
#        [ 22, 116, 232],
#        [ 27, 114, 230],
#        [ 27, 114, 229],
#        [ 23, 112, 228],
#        [ 24, 113, 229],
#        [ 24, 113, 229],
#        [ 25, 114, 230],
#        [ 24, 113, 229],
#        [ 23, 112, 228],
#        [ 22, 111, 227],
#        [ 21, 110, 226],
#        [ 21, 110, 226],
#        [ 20, 109, 225],
#        [ 19, 108, 224],
#        [ 19, 108, 224],
#        [ 19, 108, 224],
#        [ 20, 109, 225],
#        [ 22, 111, 227],
#        [ 22, 111, 227],
#        [ 26, 115, 231],
#        [ 26, 115, 231],
#        [ 25, 114, 230],
#        [ 24, 113, 229],
#        [ 23, 112, 228],
#        [ 22, 111, 227],
#        [ 21, 110, 226],
#        [ 21, 110, 226],
#        [ 28, 117, 233],
#        [ 28, 117, 233],
#        [ 27, 116, 232],
#        [ 27, 116, 232],
#        [ 27, 116, 232],
#        [ 29, 118, 234],
# ...

# %%
plt.imshow(arr)
